# %%
a = 20
b = 20 
print(a+b)
# Out:
# 40

# %%
a = 390
b = 200
print(a-b)
# Out:
# 190

# %%
A = 2
B = 3
print(A>B & B<A)
# Out:
# False

# %%
a = 645
b = 756
print(a<b | b<a)
# Out:
# False

# %%
a = 525
b = 562
print(a!=b)
# Out:
# True

# %%
a = 526
b = 235
print(a==b)
# Out:
# False

# %%
#negative or positive 
num = int(input("Enter a number:"))

if num > 0:
    print("Positve")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positve

# %%
#odd or even number
num = int(input("Enter a number"))

if num %2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
C#Greatest of two numbers
a = 6
b = 8

if a>b:
    print("a is greater than b")
else:
    print("b is greather than a")
# Out:
# b is greather than a

# %%
#Greatest of two numbers
a = int(input("Enter a number"))
b = int(input("Enter a number"))

if a>B:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# a is greater than b

# %%
#Greatest of Three Numbers
a = 792
b = 6772
c = 84

if a>b and a>c:
    print("a is greater")
elif b>a and b>c:
    print("b is greater")
else:
    print("c is greater")
# Out:
# b is greater

# %%
Greatest of Three Numbers or four
a = 25
b = 58
c = 36
d = 15

if a>b and a>c and a>d:
    print("a is greater")
elif b>a and b>c and b>d:
    print("b is greater")
elif c>a and c>b and c>d:
    print("c is greater")
else:
    print("d is greater")
# Out:
# b is greater

# %%
#Program 3 — Voting Eligibility

a = int(input("Enter a number"))

if a >= 18:
    print(" you are eligible to vote")
else:
    print("you are  not eligible to  vote ")
# Out:
# you are  not eligible to  vote

# %%
#score card
num = int(input("Enter a number"))

if num>=35 and num <=59:
    print("you have passed")
elif num>=60 and num <=84 :
    print("you have secured fist class")
elif num>=85:
    print("You have topped")
else:
    print("you have failed")
# Out:
# you have secured fist class

# %%
#calculator
a = float(input("Enter a number: "))
b = float(input("Enter a number: "))
operator=input("enter operator :")


if operator == "+":
    print(a+b)

elif operator =="-":
    print(a-b)
elif operator == "*":
    print(a*b)
elif operator == "/":
    print(a/b)
else:
    print("invalid operator")
# Out:
# 121.0
